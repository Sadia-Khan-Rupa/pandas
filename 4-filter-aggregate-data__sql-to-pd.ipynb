# %% [markdown]
# # From SQL to Pandas Challenge 4

# %%
# import libraries
import pandas as pd

# load data
# This code is made to load our data stored on Google Drive
def gd_path(file_id):
    """Generate a shareable link from Google Drive file id."""
    return f"https://drive.google.com/uc?export=download&id={file_id}"

# Google Drive file ids
files_id = {
    "titles": "1PLdn50N9GRa53ZbuVWo0l47F_IXdvlEm",
    "sales": "1fzFc9rwYmVIPaGOFmhLVxCi3kg19vNU2",
    "publishers": "1s9E8_AVOziTrowb3wyh2jg3PV763VOyq",
    "employee": "1h9mUjsVqpP74b1w0x7KOw37n_n9Ulkt5",
    "authors": "1fEF89Nhe61EebAljKlwFwfEuokK0o6aJ"
}

# Read data from Google Drive
sales = pd.read_csv(gd_path(files_id["sales"]), sep=";")
authors = pd.read_csv(gd_path(files_id["authors"]), sep=";")
publishers = pd.read_csv(gd_path(files_id["publishers"]), sep=";")
titles = pd.read_csv(gd_path(files_id["titles"]), sep=";")
employee = pd.read_csv(gd_path(files_id["employee"]), sep=";")

# %% [markdown]
# ## 1.&nbsp;From how many different states are our authors?

# %%
distinct_values=authors['state'].unique()
total_states=len(distinct_values)
total_states
# Out:
# 8

# %% [markdown]
# ### Hint:

# %% [markdown]
# In SQL the syntax is:
#
# ```sql
# SELECT COUNT(DISTINCT state)
# FROM authors;
# ```

# %% [markdown]
# ## 2.&nbsp;How many publishers are based in the USA?

# %%
len(publishers.loc[(publishers['country']=='USA'),('pub_id')])
# Out:
# 6

# %% [markdown]
# ### Hint:

# %% [markdown]
# In SQL the syntax is:
#
# ```sql
# SELECT  COUNT(pub_id)
# FROM publishers
# WHERE country ="USA" ;
# ```

# %% [markdown]
# ## 3.&nbsp;What's the average quantity of titles sold per sale by store 7131?

# %%
sales.loc[(sales['stor_id']==7131),(['qty'])].mean()
# Out:
# qty    21.666667
# dtype: float64

# %% [markdown]
# ### Hint:

# %% [markdown]
# In SQL the syntax is:
#
# ```sql
# SELECT AVG(qty)
# FROM sales
# WHERE stor_id=7131;
# ```

# %% [markdown]
# ## 4.&nbsp;When was the employee with the highest level hired?

# %%
employee.sort_values(by=['job_lvl'],ascending=False).loc[:,(['hire_date'])].head(1)
# Out:
#               hire_date
# 26  1989-03-01 00:00:00

# %% [markdown]
# ### Hint:

# %% [markdown]
# In SQL the syntax is:
#
# ```sql
# SELECT hire_date
# FROM employee
# ORDER BY job_lvl DESC
# LIMIT 1;
# ```

# %% [markdown]
# ## 5.&nbsp;What's the average price of psychology books?

# %%
(titles.loc[titles['type']=='psychology',('price')]).mean()
# Out:
# 13.504

# %% [markdown]
# ### Hint:

# %% [markdown]
# In SQL the syntax is:
#
# ```sql
# SELECT AVG(price)
# FROM titles
# WHERE type = "psychology";
# ```

# %% [markdown]
# ## 6.&nbsp;Which category of books has had more year-to-date sales, "business" or "popular_comp"? You can write two queries to answer this question.

# %% [markdown]
# ### business

# %%
titles.loc[(titles['type']=='business'),('ytd_sales')].sum()
# Out:
# 30788

# %% [markdown]
# ### Hint:

# %% [markdown]
# In SQL the syntax is:
#
# ```sql
# SELECT SUM(ytd_sales), type
# FROM titles
# WHERE type = "business";
# ```

# %% [markdown]
# ### popular_comp

# %%
sales_popular_comp=titles.loc[(titles['type']=='popular_comp'),('ytd_sales','type')]
sales_popular_comp['ytd_sales'].sum()
# Out:
# 12875

# %% [markdown]
# ### Hint:

# %% [markdown]
# In SQL the syntax is:
#
# ```sql
# SELECT SUM(ytd_sales), type
# FROM titles
# WHERE type = "popular_comp";
# ```

# %% [markdown]
# ## 7.&nbsp;What's the title and the price of the most expensive book?

# %%
titles.sort_values(by=['price'],ascending=False).loc[:,('title','price')].head(1)
# Out:
#                       title  price
# 7  But Is It User Friendly?  22.95

# %% [markdown]
# ### Hint:

# %% [markdown]
# In SQL the syntax is:
#
# ```sql
# SELECT title, price
# FROM titles
# ORDER BY price DESC
# LIMIT 1;
# ```

# %% [markdown]
# ## 8.&nbsp;What's the price of the most expensive psychology book?

# %%
titles.sort_values(by=['price'],ascending=False).loc[(titles['type']=='psychology'),('title','price')].head(1)
# Out:
#                                                 title  price
# 10  Computer Phobic AND Non-Phobic Individuals: Be...  21.59

# %% [markdown]
# ### Hint:

# %% [markdown]
# In SQL the syntax is:
#
# ```sql
# SELECT MAX(price)
# FROM titles
# WHERE type = "psychology";
# ```

# %% [markdown]
# ## 9.&nbsp;How many authors live in either San Jose or Salt Lake City?

# %%
len(authors.loc[(authors['city']=='San Jose') | (authors['city']=='Salt Lake City'), ('au_id')])
# Out:
# 3

# %% [markdown]
# ### Hint:

# %% [markdown]
# In SQL the syntax is:
#
# ```sql
# SELECT COUNT(au_id)
# FROM authors
# WHERE (city = "San Jose"
# OR city = "Salt Lake City");
# ```
